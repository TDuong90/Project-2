# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as sts
import numpy as np

# %%
file = "updated_traffic_data_final.csv"
original_df = pd.read_csv(file)
original_df.head()
# Out:
#    Unnamed: 0  DR_Number        Date Time_of_Day Date_Occurred  Time_Occurred  \
# 0           1  191504179  2019-01-01    12:00 AM    2019-01-01              5
# 1           3  191504198  2019-01-01     3:00 PM    2019-01-01           1500
# 2           4  190404052  2019-01-01    10:00 PM    2019-01-01           2230
# 3           5  190404036  2019-01-01    12:00 PM    2019-01-01           1200
# 4           7  192104017  2019-01-01     1:00 PM    2019-01-01           1340
#
#    Area_ID    Area_Name  Reporting_District  Crime_Code  ...  \
# 0       15  N Hollywood                1514         997  ...
# 1       15  N Hollywood                1526         997  ...
# 2        4   Hollenbeck                 469         997  ...
# 3        4   Hollenbeck                 477         997  ...
# 4       21      Topanga                2134         997  ...
#
#                                        MO_Codes Victim_Age  Victim_Sex  \
# ...

# %%
original_df.drop(['Unnamed: 0'], axis=1, inplace=True)
original_df
# Out:
#        DR_Number        Date Time_of_Day Date_Occurred  Time_Occurred  \
# 0      191504179  2019-01-01    12:00 AM    2019-01-01              5
# 1      191504198  2019-01-01     3:00 PM    2019-01-01           1500
# 2      190404052  2019-01-01    10:00 PM    2019-01-01           2230
# 3      190404036  2019-01-01    12:00 PM    2019-01-01           1200
# 4      192104017  2019-01-01     1:00 PM    2019-01-01           1340
# ...          ...         ...         ...           ...            ...
# 46751  190721628  2019-12-31    11:00 AM    2019-12-31           1130
# 46752  201604241  2019-12-31     6:00 AM    2019-12-31            650
# 46753  190721627  2019-12-31    11:00 AM    2019-12-31           1125
# 46754  190418571  2019-12-31    11:00 AM    2019-12-31           1150
# 46755  191324771  2019-12-31     8:00 AM    2019-12-31            800
#
#        Area_ID    Area_Name  Reporting_District  Crime_Code  \
# 0           15  N Hollywood                1514         997
# ...

# %%
original_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46756 entries, 0 to 46755
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   DR_Number               46756 non-null  int64
#  1   Date                    46756 non-null  object
#  2   Time_of_Day             46756 non-null  object
#  3   Date_Occurred           46756 non-null  object
#  4   Time_Occurred           46756 non-null  int64
#  5   Area_ID                 46756 non-null  int64
#  6   Area_Name               46756 non-null  object
#  7   Reporting_District      46756 non-null  int64
#  8   Crime_Code              46756 non-null  int64
#  9   Crime_Code_Description  46756 non-null  object
#  10  MO_Codes                46756 non-null  object
#  11  Victim_Age              46756 non-null  int64
#  12  Victim_Sex              46756 non-null  object
#  13  Premise_Code            46756 non-null  int64
# ...

# %%
original_df.to_csv("traffic_data_clean_final.csv", index=False)
