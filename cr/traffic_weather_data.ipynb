# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as sts
import numpy as np

# %%
file = "joined_traffic_weather.csv"
original_df = pd.read_csv(file)
original_df.head()
# Out:
#          Date Time_of_Day  Max  Min  Average  Precipitation  Victim_Age  \
# 0  2019-01-01    12:00 AM   62   38     50.0            0.0          30
# 1  2019-01-01     3:00 PM   62   38     50.0            0.0          74
# 2  2019-01-01    10:00 PM   62   38     50.0            0.0          23
# 3  2019-01-01    12:00 PM   62   38     50.0            0.0          72
# 4  2019-01-01     1:00 PM   62   38     50.0            0.0          46
#
#   Victim_Sex  DR_Number  Time_Occurred  ...  Crime_Code  \
# 0          M  191504179              5  ...         997
# 1          M  191504198           1500  ...         997
# 2          F  190404052           2230  ...         997
# 3          M  190404036           1200  ...         997
# 4          F  192104017           1340  ...         997
#
#   Crime_Code_Description                                      MO_Codes  \
# 0      TRAFFIC COLLISION       3006 3030 3028 3037 3101 3401 3701 4026
# ...

# %%
original_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46756 entries, 0 to 46755
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    46756 non-null  object
#  1   Time_of_Day             46756 non-null  object
#  2   Max                     46756 non-null  int64
#  3   Min                     46756 non-null  int64
#  4   Average                 46756 non-null  float64
#  5   Precipitation           46756 non-null  float64
#  6   Victim_Age              46756 non-null  int64
#  7   Victim_Sex              46756 non-null  object
#  8   DR_Number               46756 non-null  int64
#  9   Time_Occurred           46756 non-null  int64
#  10  Area_ID                 46756 non-null  int64
#  11  Area_Name               46756 non-null  object
#  12  Reporting_District      46756 non-null  int64
#  13  Crime_Code              46756 non-null  int64
# ...
