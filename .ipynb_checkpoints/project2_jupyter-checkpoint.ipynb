# %%
 # Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as sts
import numpy as np
import re
import string

# %%
file = "traffic_data.csv"

# %%
original_df = pd.read_csv(file)
original_df.head()
# Out:
#    DR Number Date Reported Date Occurred  Time Occurred  Area ID    Area Name  \
# 0  190211527     5/18/2019     5/18/2019            110        2      Rampart
# 1  110518459    10/11/2011    10/11/2011           1735        5       Harbor
# 2  180618348      8/9/2018      8/9/2018           1830        6    Hollywood
# 3  120312271      5/9/2012      5/9/2012            845        3    Southwest
# 4  121215287     6/13/2012     6/13/2012            745       12  77th Street
#
#    Reporting District  Crime Code Crime Code Description  \
# 0                 279         997      TRAFFIC COLLISION
# 1                 505         997      TRAFFIC COLLISION
# 2                 665         997      TRAFFIC COLLISION
# 3                 331         997      TRAFFIC COLLISION
# 4                1208         997      TRAFFIC COLLISION
#
#                                        MO Codes  Victim Age Victim Sex  \
# 0                      3101 3401 3701 3004 3030        33.0          F
# 1                                           506        27.0          F
# 2  3004 3028 3030 3035 3036 3101 3401 3701 4006        33.0          M
# 3                                           NaN        51.0          M
# 4                                           605        48.0          F
#
#   Victim Descent  Premise Code Premise Description  \
# 0              H         101.0              STREET
# 1              O         101.0              STREET
# 2              W         101.0              STREET
# 3              B         101.0              STREET
# 4              B         101.0              STREET
#
#                            Address                     Cross Street  \
# 0                            UNION                     JAMES M WOOD
# 1                          VERMONT                             KNOX
# 2  FRANKLIN                     AV                           ARGYLE
# 3  LA BREA                      AV  JEFFERSON                    BL
# 4  48TH                         ST                         FIGUEROA
#
#                Location
# 0  (34.0508, -118.2731)
# 1  (33.8542, -118.2905)
# 2  (34.1052, -118.3252)
# 3  (34.0255, -118.3548)
# 4  (33.9997, -118.2827)

# %%
renamed_df = original_df.rename(columns={"DR Number":"DR_Number",
                                         "Date Reported":"Date_Reported",
                                         "Date Occurred":"Date_Occurred",
                                         "Time Occurred":"Time_Occurred",
                                         "Area ID":"Area_ID",
                                         "Area Name":"Area_Name",
                                         "Reporting District":"Reporting_District",
                                         "Crime Code":"Crime_Code",
                                         "Crime Code Description":"Crime_Code_Description",
                                         "MO Codes":"MO_Codes",
                                         "Victim Age":"Victim_Age",
                                         "Victim Sex":"Victim_Sex",
                                         "Victim Descent":"Victim_Descent",
                                         "Premise Code":"Premise_Code",
                                         "Premise Description":"Premise_Description",
                                         "Cross Street":"Cross_Street",
                                         })
renamed_df.head()
# Out:
#    DR_Number Date_Reported Date_Occurred  Time_Occurred  Area_ID    Area_Name  \
# 0  190211527     5/18/2019     5/18/2019            110        2      Rampart
# 1  110518459    10/11/2011    10/11/2011           1735        5       Harbor
# 2  180618348      8/9/2018      8/9/2018           1830        6    Hollywood
# 3  120312271      5/9/2012      5/9/2012            845        3    Southwest
# 4  121215287     6/13/2012     6/13/2012            745       12  77th Street
#
#    Reporting_District  Crime_Code Crime_Code_Description  \
# 0                 279         997      TRAFFIC COLLISION
# 1                 505         997      TRAFFIC COLLISION
# 2                 665         997      TRAFFIC COLLISION
# 3                 331         997      TRAFFIC COLLISION
# 4                1208         997      TRAFFIC COLLISION
#
#                                        MO_Codes  Victim_Age Victim_Sex  \
# 0                      3101 3401 3701 3004 3030        33.0          F
# 1                                           506        27.0          F
# 2  3004 3028 3030 3035 3036 3101 3401 3701 4006        33.0          M
# 3                                           NaN        51.0          M
# 4                                           605        48.0          F
#
#   Victim_Descent  Premise_Code Premise_Description  \
# 0              H         101.0              STREET
# 1              O         101.0              STREET
# 2              W         101.0              STREET
# 3              B         101.0              STREET
# 4              B         101.0              STREET
#
#                            Address                     Cross_Street  \
# 0                            UNION                     JAMES M WOOD
# 1                          VERMONT                             KNOX
# 2  FRANKLIN                     AV                           ARGYLE
# 3  LA BREA                      AV  JEFFERSON                    BL
# 4  48TH                         ST                         FIGUEROA
#
#                Location
# 0  (34.0508, -118.2731)
# 1  (33.8542, -118.2905)
# 2  (34.1052, -118.3252)
# 3  (34.0255, -118.3548)
# 4  (33.9997, -118.2827)

# %%
renamed_df.Date_Occurred = pd.to_datetime(renamed_df.Date_Occurred).dt.strftime('%Y-%m-%d')
renamed_df.Date_Reported = pd.to_datetime(renamed_df.Date_Reported).dt.strftime('%Y-%m-%d')
renamed_df.head()
# Out:
#    DR_Number Date_Reported Date_Occurred  Time_Occurred  Area_ID    Area_Name  \
# 0  190211527    2019-05-18    2019-05-18            110        2      Rampart
# 1  110518459    2011-10-11    2011-10-11           1735        5       Harbor
# 2  180618348    2018-08-09    2018-08-09           1830        6    Hollywood
# 3  120312271    2012-05-09    2012-05-09            845        3    Southwest
# 4  121215287    2012-06-13    2012-06-13            745       12  77th Street
#
#    Reporting_District  Crime_Code Crime_Code_Description  \
# 0                 279         997      TRAFFIC COLLISION
# 1                 505         997      TRAFFIC COLLISION
# 2                 665         997      TRAFFIC COLLISION
# 3                 331         997      TRAFFIC COLLISION
# 4                1208         997      TRAFFIC COLLISION
#
#                                        MO_Codes  Victim_Age Victim_Sex  \
# 0                      3101 3401 3701 3004 3030        33.0          F
# 1                                           506        27.0          F
# 2  3004 3028 3030 3035 3036 3101 3401 3701 4006        33.0          M
# 3                                           NaN        51.0          M
# 4                                           605        48.0          F
#
#   Victim_Descent  Premise_Code Premise_Description  \
# 0              H         101.0              STREET
# 1              O         101.0              STREET
# 2              W         101.0              STREET
# 3              B         101.0              STREET
# 4              B         101.0              STREET
#
#                            Address                     Cross_Street  \
# 0                            UNION                     JAMES M WOOD
# 1                          VERMONT                             KNOX
# 2  FRANKLIN                     AV                           ARGYLE
# 3  LA BREA                      AV  JEFFERSON                    BL
# 4  48TH                         ST                         FIGUEROA
#
#                Location
# 0  (34.0508, -118.2731)
# 1  (33.8542, -118.2905)
# 2  (34.1052, -118.3252)
# 3  (34.0255, -118.3548)
# 4  (33.9997, -118.2827)

# %%
occurred_df = renamed_df.loc[renamed_df['Date_Occurred'].between('2019-01-01','2019-12-31', inclusive=True)]
sorted_df = occurred_df.sort_values("Date_Occurred", ascending=True).reset_index(drop=True)
sorted_df.head()
# Out:
#    DR_Number Date_Reported Date_Occurred  Time_Occurred  Area_ID    Area_Name  \
# 0  191704034    2019-01-01    2019-01-01           1930       17   Devonshire
# 1  191504179    2019-01-04    2019-01-01              5       15  N Hollywood
# 2  192104002    2019-01-01    2019-01-01            720       21      Topanga
# 3  191504198    2019-01-01    2019-01-01           1500       15  N Hollywood
# 4  190404052    2019-01-02    2019-01-01           2230        4   Hollenbeck
#
#    Reporting_District  Crime_Code Crime_Code_Description  \
# 0                1774         997      TRAFFIC COLLISION
# 1                1514         997      TRAFFIC COLLISION
# 2                2129         997      TRAFFIC COLLISION
# 3                1526         997      TRAFFIC COLLISION
# 4                 469         997      TRAFFIC COLLISION
#
#                                        MO_Codes  Victim_Age Victim_Sex  \
# 0                                           NaN        23.0          F
# 1       3006 3030 3028 3037 3101 3401 3701 4026        30.0          M
# 2  3011 3025 3034 3037 3101 3401 3701 4026 3039         NaN          M
# 3  0605 3101 3004 3036 3030 3028 3401 3701 4015        74.0          M
# 4                 3101 3401 3701 3004 3030 0605        23.0          F
#
#   Victim_Descent  Premise_Code Premise_Description  \
# 0              H         101.0              STREET
# 1              H         101.0              STREET
# 2              W         101.0              STREET
# 3              H         101.0              STREET
# 4              H         101.0              STREET
#
#                            Address                     Cross_Street  \
# 0  LA BREA                      AV  WASHINGTON                   BL
# 1  GENTRY                       AV  VANOWEN                      ST
# 2  ROSCOE                       BL  WINNETKA                     AV
# 3  VICTORY                      BL  TUJUNGA                      AV
# 4  1ST                          ST  SAVANNAH                     ST
#
#                Location
# 0  (34.2428, -118.5253)
# 1   (34.194, -118.3932)
# 2   (34.2202, -118.571)
# 3   (34.1867, -118.379)
# 4  (34.0333, -118.1946)

# %%
sorted_df = sorted_df.drop(["Date_Reported"], axis=1)

# %%
cleaned_df = sorted_df.dropna()
cleaned_df.count()
# Out:
# DR_Number                 46575
# Date_Occurred             46575
# Time_Occurred             46575
# Area_ID                   46575
# Area_Name                 46575
# Reporting_District        46575
# Crime_Code                46575
# Crime_Code_Description    46575
# MO_Codes                  46575
# Victim_Age                46575
# Victim_Sex                46575
# Victim_Descent            46575
# Premise_Code              46575
# Premise_Description       46575
# Address                   46575
# Cross_Street              46575
# Location                  46575
# dtype: int64

# %%
cleaned_df.head()
# Out:
#    DR_Number Date_Occurred  Time_Occurred  Area_ID    Area_Name  \
# 1  191504179    2019-01-01              5       15  N Hollywood
# 3  191504198    2019-01-01           1500       15  N Hollywood
# 4  190404052    2019-01-01           2230        4   Hollenbeck
# 5  190404036    2019-01-01           1200        4   Hollenbeck
# 7  192104017    2019-01-01           1340       21      Topanga
#
#    Reporting_District  Crime_Code Crime_Code_Description  \
# 1                1514         997      TRAFFIC COLLISION
# 3                1526         997      TRAFFIC COLLISION
# 4                 469         997      TRAFFIC COLLISION
# 5                 477         997      TRAFFIC COLLISION
# 7                2134         997      TRAFFIC COLLISION
#
#                                        MO_Codes  Victim_Age Victim_Sex  \
# 1       3006 3030 3028 3037 3101 3401 3701 4026        30.0          M
# 3  0605 3101 3004 3036 3030 3028 3401 3701 4015        74.0          M
# 4                 3101 3401 3701 3004 3030 0605        23.0          F
# 5                 3101 3401 3701 3004 3026 3036        72.0          M
# 7       3004 3037 3034 3025 3101 3401 3701 4026        46.0          F
#
#   Victim_Descent  Premise_Code Premise_Description  \
# 1              H         101.0              STREET
# 3              H         101.0              STREET
# 4              H         101.0              STREET
# 5              H         101.0              STREET
# 7              W         101.0              STREET
#
#                            Address                     Cross_Street  \
# 1  GENTRY                       AV  VANOWEN                      ST
# 3  VICTORY                      BL  TUJUNGA                      AV
# 4  1ST                          ST  SAVANNAH                     ST
# 5                         WHITTIER                             ORME
# 7  CARLSON                      CI  SHERMAN                      WY
#
#                Location
# 1   (34.194, -118.3932)
# 3   (34.1867, -118.379)
# 4  (34.0333, -118.1946)
# 5  (34.0325, -118.2115)
# 7   (34.201, -118.6129)

# %%
test = pd.DataFrame(cleaned_df)
test.head()
# Out:
#    DR_Number Date_Occurred  Time_Occurred  Area_ID    Area_Name  \
# 1  191504179    2019-01-01              5       15  N Hollywood
# 3  191504198    2019-01-01           1500       15  N Hollywood
# 4  190404052    2019-01-01           2230        4   Hollenbeck
# 5  190404036    2019-01-01           1200        4   Hollenbeck
# 7  192104017    2019-01-01           1340       21      Topanga
#
#    Reporting_District  Crime_Code Crime_Code_Description  \
# 1                1514         997      TRAFFIC COLLISION
# 3                1526         997      TRAFFIC COLLISION
# 4                 469         997      TRAFFIC COLLISION
# 5                 477         997      TRAFFIC COLLISION
# 7                2134         997      TRAFFIC COLLISION
#
#                                        MO_Codes  Victim_Age Victim_Sex  \
# 1       3006 3030 3028 3037 3101 3401 3701 4026        30.0          M
# 3  0605 3101 3004 3036 3030 3028 3401 3701 4015        74.0          M
# 4                 3101 3401 3701 3004 3030 0605        23.0          F
# 5                 3101 3401 3701 3004 3026 3036        72.0          M
# 7       3004 3037 3034 3025 3101 3401 3701 4026        46.0          F
#
#   Victim_Descent  Premise_Code Premise_Description  \
# 1              H         101.0              STREET
# 3              H         101.0              STREET
# 4              H         101.0              STREET
# 5              H         101.0              STREET
# 7              W         101.0              STREET
#
#                            Address                     Cross_Street  \
# 1  GENTRY                       AV  VANOWEN                      ST
# 3  VICTORY                      BL  TUJUNGA                      AV
# 4  1ST                          ST  SAVANNAH                     ST
# 5                         WHITTIER                             ORME
# 7  CARLSON                      CI  SHERMAN                      WY
#
#                Location
# 1   (34.194, -118.3932)
# 3   (34.1867, -118.379)
# 4  (34.0333, -118.1946)
# 5  (34.0325, -118.2115)
# 7   (34.201, -118.6129)

# %%
test_1 = test.Location.str.strip()
test_1
# Out:
# 1         (34.194, -118.3932)
# 3         (34.1867, -118.379)
# 4        (34.0333, -118.1946)
# 5        (34.0325, -118.2115)
# 7         (34.201, -118.6129)
#                  ...
# 56606    (34.0414, -118.3539)
# 56608    (34.2393, -118.3938)
# 56610     (34.065, -118.3386)
# 56611     (34.0566, -118.211)
# 56612    (33.9858, -118.2739)
# Name: Location, Length: 46575, dtype: object

# %%
# victim age
plt.hist(cleaned_df['Victim_Age'])
plt.xlabel('Age')
plt.ylabel('Counts')
plt.show()
print(sts.normaltest(cleaned_df["Victim_Age"].sample(46575)))
# Out:
# NormaltestResult(statistic=4286.567031825999, pvalue=0.0)

# %%
# reporting district
plt.hist(cleaned_df['Reporting_District'])
plt.xlabel('District')
plt.ylabel('Counts')
plt.show()
print(sts.normaltest(cleaned_df["Reporting_District"].sample(46575)))
# Out:
# NormaltestResult(statistic=22413.674232202506, pvalue=0.0)

# %%
# time occurred
plt.hist(cleaned_df['Time_Occurred'])
plt.xlabel('District')
plt.ylabel('Counts')
plt.show()
print(sts.normaltest(cleaned_df["Time_Occurred"].sample(46575)))
# Out:
# NormaltestResult(statistic=2228.3376106602445, pvalue=0.0)

# %%
# date occurred
plt.hist(cleaned_df["Date_Occurred"])
plt.xlabel('Date')
plt.ylabel('Counts')
plt.show()
print(sts.normaltest(cleaned_df["Time_Occurred"].sample(46575)))
# Out:
# NormaltestResult(statistic=2228.337610660245, pvalue=0.0)

# %%
cleaned_df.to_csv("cleaned_traffic_data.csv")

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46575 entries, 1 to 56612
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   DR_Number               46575 non-null  int64
#  1   Date_Occurred           46575 non-null  object
#  2   Time_Occurred           46575 non-null  int64
#  3   Area_ID                 46575 non-null  int64
#  4   Area_Name               46575 non-null  object
#  5   Reporting_District      46575 non-null  int64
#  6   Crime_Code              46575 non-null  int64
#  7   Crime_Code_Description  46575 non-null  object
#  8   MO_Codes                46575 non-null  object
#  9   Victim_Age              46575 non-null  float64
#  10  Victim_Sex              46575 non-null  object
#  11  Victim_Descent          46575 non-null  object
#  12  Premise_Code            46575 non-null  float64
#  13  Premise_Description     46575 non-null  object
#  14  Address                 46575 non-null  object
#  15  Cross_Street            46575 non-null  object
#  16  Location                46575 non-null  object
# dtypes: float64(2), int64(5), object(10)
# memory usage: 6.4+ MB
